# %% [markdown]
# Here is some basic code to start machine learning for our dataset. Use a copy of this to get the data for your own model.
#
# -- Zaq

# %%
import pandas

# %%
df = pandas.read_csv('../out/merged_data.csv')
# df.head(3)

# %%
labels = df.columns
# labels

# %%
X = df.loc[
    :,
    [
        'release_year', 'duration_ms.x', 'explicit', 
        'mode', 'speechiness', 'acousticness',
        'instrumentalness', 'liveness', 'valence',
        'tempo', 'time_signature'
    ]
] 
# X.head(3)

# %%
Y = df.loc[
    :,
    [
        'delta: sad to happy',
        'delta: calm to energetic',
        'delta: relaxed to stressed'
    ]
] 
# Y.head()
